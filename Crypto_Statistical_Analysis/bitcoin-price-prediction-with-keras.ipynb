# %%
# %%time
# Import libraries
# !pip3 install numpy # linear algebra
# !pip3 install pandas # data processing, CSV file I/O (e.g. pd.read_csv)
# !pip3 install plotly
# !pip3 install yfinance
# !pip3 install modin
# !pip3 install keras
# !pip3 install seaborn
# !pip3 install requests
# !pip3 install quantstats
# !pip3 install sklearn.metrics
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: numpy in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (1.21.5)
# Requirement already satisfied: pandas in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: plotly in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (5.6.0)
# Requirement already satisfied: six in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: yfinance in /Users/owner/.local/lib/python3.7/site-packages (0.1.63)
# Requirement already satisfied: numpy>=1.15 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pandas>=0.24 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from yfinance) (1.3.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/owner/.local/lib/python3.7/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: requests>=2.20 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in /Users/owner/.local/lib/python3.7/site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/owner/.local/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests>=2.20->yfinance) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests>=2.20->yfinance) (3.3)
# Requirement already satisfied: modin in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from modin) (1.21.5)
# Requirement already satisfied: packaging in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from modin) (21.3)
# Requirement already satisfied: fsspec in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from modin) (2022.5.0)
# Requirement already satisfied: pandas==1.3.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from modin) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas==1.3.5->modin) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas==1.3.5->modin) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas==1.3.5->modin) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from packaging->modin) (3.0.4)
# Requirement already satisfied: keras in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (2.6.0)
# Requirement already satisfied: seaborn in /Users/owner/.local/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib>=2.2 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: scipy>=1.0 in /Users/owner/.local/lib/python3.7/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: numpy>=1.15 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: typing-extensions in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (3.10.0.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.15.0)
# Requirement already satisfied: requests in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/owner/.local/lib/python3.7/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests) (3.3)
# Requirement already satisfied: quantstats in /Users/owner/.local/lib/python3.7/site-packages (0.0.34)
# Requirement already satisfied: pandas>=0.24.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from quantstats) (1.3.5)
# Requirement already satisfied: seaborn>=0.9.0 in /Users/owner/.local/lib/python3.7/site-packages (from quantstats) (0.11.2)
# Requirement already satisfied: tabulate>=0.8.0 in /Users/owner/.local/lib/python3.7/site-packages (from quantstats) (0.8.9)
# Requirement already satisfied: numpy>=1.16.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from quantstats) (1.21.5)
# Requirement already satisfied: yfinance>=0.1.55 in /Users/owner/.local/lib/python3.7/site-packages (from quantstats) (0.1.63)
# Requirement already satisfied: scipy>=1.2.0 in /Users/owner/.local/lib/python3.7/site-packages (from quantstats) (1.7.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from quantstats) (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=3.0.0->quantstats) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=3.0.0->quantstats) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=3.0.0->quantstats) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=3.0.0->quantstats) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=3.0.0->quantstats) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=3.0.0->quantstats) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib>=3.0.0->quantstats) (2.8.2)
# Requirement already satisfied: typing-extensions in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=3.0.0->quantstats) (3.10.0.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pandas>=0.24.0->quantstats) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->quantstats) (1.15.0)
# Requirement already satisfied: requests>=2.20 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from yfinance>=0.1.55->quantstats) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in /Users/owner/.local/lib/python3.7/site-packages (from yfinance>=0.1.55->quantstats) (4.6.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/owner/.local/lib/python3.7/site-packages (from yfinance>=0.1.55->quantstats) (0.0.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/owner/.local/lib/python3.7/site-packages (from requests>=2.20->yfinance>=0.1.55->quantstats) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests>=2.20->yfinance>=0.1.55->quantstats) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests>=2.20->yfinance>=0.1.55->quantstats) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests>=2.20->yfinance>=0.1.55->quantstats) (2022.5.18.1)
# ERROR: Could not find a version that satisfies the requirement sklearn.metrics (from versions: none)
# ERROR: No matching distribution found for sklearn.metrics
# Requirement already satisfied: matplotlib in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: typing-extensions in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# CPU times: user 1.28 s, sys: 473 ms, total: 1.75 s
# Wall time: 1min 21s

# %%
# %%time
# Import libraries
# !pip3 install tensorflow
import tensorflow
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import modin

from plotly.subplots import make_subplots
import plotly.graph_objects as go

from keras.models import Sequential
from keras.layers import LSTM,Dense,Dropout,AveragePooling1D,Reshape

from sklearn.metrics import mean_absolute_error
# Out:
# Requirement already satisfied: tensorflow in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (2.6.5)
# Requirement already satisfied: six~=1.15.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: gast==0.4.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: keras<2.7,>=2.6.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: google-pasta~=0.2 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: clang~=5.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (5.0)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp37-cp37m-macosx_10_9_x86_64.whl (15.6 MB)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (1.46.3)
# Requirement already satisfied: tensorboard<2.7,>=2.6.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: tensorflow-estimator<2.7,>=2.6.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: typing-extensions<3.11,>=3.7 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: h5py~=3.1.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: cached-property in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (61.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.1.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (1.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/owner/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/owner/opt/anaconda3/envs/Crypto_Data/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (3.2.0)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Successfully installed numpy-1.19.5

# %%
# %%time
#Import data
data = pd.read_csv('archive/crypto_tradinds.csv') # will come up with better naming schema
#data = pd.read_csv('../input/historical-data-on-the-trading-of-cryptocurrencies/crypto_tradinds.csv')
data.head(50)

# %%
# %%time
#Select Bitcoin Data
btc_data = data[data['ticker']=='BTC']
btc_data.tail(20)

# %%
# %%time
#Check data
btc_data.nunique()

# %%
# %%time
btc_data['price_btc'].unique()

# %%
# %%time
#Check value 0 in 'price_btc'
btc_data_0 = btc_data[data['price_btc']==0]
btc_data_0.tail(20)

# %% [markdown]
# Previous code return only 1 row. Value '0' in column 'price_btc' for BTC must be mistake in dataset.

# %%
# %%time
#Drop columns with 1 value (and 'price_btc' with one mistake)
drop_columns_list = btc_data.nunique()[btc_data.nunique()<=2].index
btc_data.drop(drop_columns_list, axis=1, inplace=True)

# %%
# %%time
#Print full graph of bitcoin price
fig = go.Figure(data=go.Scatter(x=btc_data['trade_date'], y=btc_data['price_usd']))
fig.show()

# %%
# %%time
# fix random seed for reproducibility
np.random.seed(42)

# %%
# %%time
def data_preproc_and_split(data,n):
    #define variables
    col = []
    for i in range(n):
        col.append('price' + str(i))
        col.append('volume' + str(i))
    train = pd.DataFrame(columns = col)
    target = pd.DataFrame(columns = ['date','price'])
    pred_convert = pd.DataFrame(columns = ['date','price'])

    #Preprocessing of data
    for i in range(1,len(data)-n-1):
        def_nom = data.loc[i-1, 'price_usd']
        for j in range(n):
            train.loc[i, 'price' + str(j)] = data.loc[i+j, 'price_usd']/def_nom-1
            train.loc[i, 'volume' + str(j)] = data.loc[i+j, 'volume']/data.loc[i+j, 'market_cap']
        target.loc[i, 'price'] = data.loc[i+n+1, 'price_usd']/def_nom-1
        target.loc[i, 'date'] = data.loc[i+n+1, 'trade_date']
        #Save start prices for convertation prediction resalt to valid prices
        pred_convert.loc[i, 'price'] = def_nom
        pred_convert.loc[i, 'date'] = data.loc[i+n+1, 'trade_date']

    #Data split
    x_train = train.iloc[:train.shape[0]-100]
    x_valid = train.iloc[train.shape[0]-100:]
    y_train = target.iloc[:target.shape[0]-100]
    y_valid = target.iloc[target.shape[0]-100:]
    y_train.drop(['date'], axis=1, inplace=True)
    y_valid.drop(['date'], axis=1, inplace=True)

    #Convert shape of data for LSTM model
    x_train = x_train.to_numpy().reshape((x_train.shape[0],n,2))
    x_valid = x_valid.to_numpy().reshape((x_valid.shape[0],n,2))
    return x_train,x_valid,y_train,y_valid,target,pred_convert

# %%
# %%time
#model
def model_gen(x,y,n,e=75,v=0):
    mod = Sequential()
    mod.add(LSTM(32,return_sequences=True,input_shape=(n,2)))
    mod.add(LSTM(64))
    mod.add(Dropout(0.35))
    mod.add(Dense(128, activation='relu'))
    mod.add(Dense(1))
    mod.compile(optimizer='adam',loss='mse')
    mod.fit(x,y,epochs=e,shuffle=False,verbose=v)
    return mod

# %%
# %%time
#Tuning, step 1: found optimal epoch for model
x_train,x_valid,y_train,y_valid,target,pred_convert = data_preproc_and_split(btc_data,15) #Create necessary datasets from start data (preprocessing and split)
y_pred = {}
mae = {'before_convert': {}, 'after_convert': {}}
R = range(25,130,25)
for i in R:
    #print (i)
    model = model_gen(x_train,y_train,15,i,0) #Model generation without output
    preds = model.predict(x_valid) #Prediction
    y_pred[i] = pd.DataFrame(preds, index=y_valid.index, columns = ['price']) #Create DataFrame from prediction results
    y_pred[i]['date'] = target['date'] #Add date column to results
    mae['before_convert'][i] = mean_absolute_error(y_valid['price'],y_pred[i]['price']) #Save Mean absolute error before price convertation
    y_pred[i]['price'] = pred_convert['price']*(y_pred[i]['price']+1) #Convert prediction results to valid price
    mae['after_convert'][i] = mean_absolute_error(btc_data.iloc[btc_data.shape[0]-100:]['price_usd'],y_pred[i]['price']) #Save Mean absolute error after price convertation

#Print results of prediction
fig = go.Figure()
fig.add_trace(go.Scatter(x=btc_data.iloc[btc_data.shape[0]-100:]['trade_date'], y=btc_data.iloc[btc_data.shape[0]-100:]['price_usd'], name='Real price'))
for i in R:
    fig.add_trace(go.Scatter(x=y_pred[i]['date'], y=y_pred[i]['price'], name='Epoch = ' + str(i)))
fig.show()
for i in R:
    print('Epoch = ' + str(i) + '. Mean absolute error before price convertation: ' + str(mae['before_convert'][i]) + '. Mean absolute error after price convertation: ' + str(mae['after_convert'][i]) + '.')

# %%
# %%time
#Tuning, step 2: found optimal size of timeframe
y_pred = {}
mae = {'before_convert': {}, 'after_convert': {}}
R = range(10,31,5)
for i in R:
    #print (i)
    x_train,x_valid,y_train,y_valid,target,pred_convert = data_preproc_and_split(btc_data,i) #Create necessary datasets from start data (preprocessing and split)
    model = model_gen(x_train,y_train,i,75,0) #Model generation without output
    preds = model.predict(x_valid) #Prediction
    y_pred[i] = pd.DataFrame(preds, index=y_valid.index, columns = ['price']) #Create DataFrame from prediction results
    y_pred[i]['date'] = target['date'] #Add date column to results
    mae['before_convert'][i] = mean_absolute_error(y_valid['price'],y_pred[i]['price']) #Save Mean absolute error before price convertation
    y_pred[i]['price'] = pred_convert['price']*(y_pred[i]['price']+1) #Convert prediction results to valid price
    mae['after_convert'][i] = mean_absolute_error(btc_data.iloc[btc_data.shape[0]-100:]['price_usd'],y_pred[i]['price']) #Save Mean absolute error after price convertation

#Print results of prediction
fig = go.Figure()
fig.add_trace(go.Scatter(x=btc_data.iloc[btc_data.shape[0]-100:]['trade_date'], y=btc_data.iloc[btc_data.shape[0]-100:]['price_usd'], name='Real price'))
for i in R:
    fig.add_trace(go.Scatter(x=y_pred[i]['date'], y=y_pred[i]['price'], name='TimeFrame Size = ' + str(i)))
fig.show()
for i in R:
    print('TimeFrame Size = ' + str(i) + '. Mean absolute error before price convertation: ' + str(mae['before_convert'][i]) + '. Mean absolute error after price convertation: ' + str(mae['after_convert'][i]) + '.')

# %%
# %%time
#Print final result
fig = go.Figure()
fig.add_trace(go.Scatter(x=btc_data.iloc[btc_data.shape[0]-100:]['trade_date'], y=btc_data.iloc[btc_data.shape[0]-100:]['price_usd'], name='Real price'))
fig.add_trace(go.Scatter(x=y_pred[15]['date'], y=y_pred[15]['price'], name='Predict price'))
fig.show()
