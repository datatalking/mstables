# %%
# dbnomics https://docs.db.nomics.world/download-data/#programming-languages

# %%
# !pip install scikit-learn
# !pip install dbnomics
# !pip install numpy
# !pip install altair
# !pip install urllib.request
# !pip install dbnomics
# !pip install vega
#!pip3 install notebook==6.5.5
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from scikit-learn) (2.2.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: dbnomics in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (1.2.6)
# Requirement already satisfied: pandas>=2.2.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from dbnomics) (2.2.3)
# Requirement already satisfied: requests>=2.32.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from dbnomics) (2.32.3)
# Requirement already satisfied: tenacity>=9.0.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from dbnomics) (9.1.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=2.2.3->dbnomics) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=2.2.3->dbnomics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=2.2.3->dbnomics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=2.2.3->dbnomics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.32.3->dbnomics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.32.3->dbnomics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.32.3->dbnomics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.32.3->dbnomics) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->dbnomics) (1.17.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (2.2.4)
# Requirement already satisfied: altair in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (5.5.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from altair) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from altair) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from altair) (1.40.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from altair) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from altair) (4.12.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.22.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jinja2->altair) (3.0.2)
# ERROR: Could not find a version that satisfies the requirement urllib.request (from versions: none)
# ERROR: No matching distribution found for urllib.request
# Requirement already satisfied: dbnomics in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (1.2.6)
# Requirement already satisfied: pandas>=2.2.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from dbnomics) (2.2.3)
# Requirement already satisfied: requests>=2.32.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from dbnomics) (2.32.3)
# Requirement already satisfied: tenacity>=9.0.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from dbnomics) (9.1.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=2.2.3->dbnomics) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=2.2.3->dbnomics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=2.2.3->dbnomics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=2.2.3->dbnomics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.32.3->dbnomics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.32.3->dbnomics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.32.3->dbnomics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.32.3->dbnomics) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->dbnomics) (1.17.0)
# Requirement already satisfied: vega in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (4.1.0)
# Requirement already satisfied: ipytablewidgets<0.4.0,>=0.3.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from vega) (0.3.2)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from vega) (1.1.1)
# Requirement already satisfied: pandas>=1.5.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from vega) (2.2.3)
# Requirement already satisfied: ipywidgets<9,>=7.5.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipytablewidgets<0.4.0,>=0.3.0->vega) (8.1.7)
# Requirement already satisfied: traitlets>=4.3.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipytablewidgets<0.4.0,>=0.3.0->vega) (5.14.3)
# Requirement already satisfied: numpy<3.0.0,>=1.10.4 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipytablewidgets<0.4.0,>=0.3.0->vega) (2.2.4)
# Requirement already satisfied: lz4 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipytablewidgets<0.4.0,>=0.3.0->vega) (4.4.4)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (7.3.2)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (7.16.6)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (6.29.5)
# Requirement already satisfied: jupyterlab in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter<2.0.0,>=1.0.0->vega) (4.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=1.5.0->vega) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=1.5.0->vega) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pandas>=1.5.0->vega) (2025.2)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (8.30.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (3.0.15)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->vega) (1.17.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (1.8.11)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (1.6.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (24.2)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->vega) (6.4.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->vega) (3.0.43)
# Requirement already satisfied: pygments in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->vega) (2.15.1)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.27.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (75.8.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->vega) (1.5.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (1.4.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (4.6.2)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (3.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.14.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.19.2)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2.0.0,>=1.0.0->vega) (4.3.7)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (2.20.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter<2.0.0,>=1.0.0->vega) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->vega) (2.5)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.3.0)
# Requirement already satisfied: executing in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.0->ipytablewidgets<0.4.0,>=0.3.0->vega) (0.2.2)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/mstables/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2.0.0,>=1.0.0->vega) (2.9.0.20250516)

# %%
import dbnomics

df = dbnomics.fetch_series('OECD', 'MEI', 'USA.B6BLTT01.CXCUSA.Q')

df
# Out:
#     @frequency provider_code dataset_code  \
# 0    quarterly          OECD          MEI
# 1    quarterly          OECD          MEI
# 2    quarterly          OECD          MEI
# 3    quarterly          OECD          MEI
# 4    quarterly          OECD          MEI
# ..         ...           ...          ...
# 250  quarterly          OECD          MEI
# 251  quarterly          OECD          MEI
# 252  quarterly          OECD          MEI
# 253  quarterly          OECD          MEI
# 254  quarterly          OECD          MEI
#
#                              dataset_name            series_code  \
# 0    Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# 1    Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# 2    Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# 3    Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# 4    Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# ..                                    ...                    ...
# 250  Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# 251  Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# 252  Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# 253  Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
# 254  Main Economic Indicators Publication  USA.B6BLTT01.CXCUSA.Q
#
#                                            series_name original_period  \
# 0    United States – Balance of payments BPM6 > Cur...         1960-Q1
# 1    United States – Balance of payments BPM6 > Cur...         1960-Q2
# 2    United States – Balance of payments BPM6 > Cur...         1960-Q3
# 3    United States – Balance of payments BPM6 > Cur...         1960-Q4
# 4    United States – Balance of payments BPM6 > Cur...         1961-Q1
# ..                                                 ...             ...
# 250  United States – Balance of payments BPM6 > Cur...         2022-Q3
# 251  United States – Balance of payments BPM6 > Cur...         2022-Q4
# 252  United States – Balance of payments BPM6 > Cur...         2023-Q1
# 253  United States – Balance of payments BPM6 > Cur...         2023-Q2
# 254  United States – Balance of payments BPM6 > Cur...         2023-Q3
#
#         period  original_value     value LOCATION   SUBJECT MEASURE FREQUENCY  \
# 0   1960-01-01           350.0     350.0      USA  B6BLTT01  CXCUSA         Q
# 1   1960-04-01           530.0     530.0      USA  B6BLTT01  CXCUSA         Q
# 2   1960-07-01           836.0     836.0      USA  B6BLTT01  CXCUSA         Q
# 3   1960-10-01          1108.0    1108.0      USA  B6BLTT01  CXCUSA         Q
# 4   1961-01-01          1239.0    1239.0      USA  B6BLTT01  CXCUSA         Q
# ..         ...             ...       ...      ...       ...     ...       ...
# 250 2022-07-01       -222757.0 -222757.0      USA  B6BLTT01  CXCUSA         Q
# 251 2022-10-01       -216154.0 -216154.0      USA  B6BLTT01  CXCUSA         Q
# 252 2023-01-01       -214472.0 -214472.0      USA  B6BLTT01  CXCUSA         Q
# 253 2023-04-01       -216805.0 -216805.0      USA  B6BLTT01  CXCUSA         Q
# 254 2023-07-01       -200304.0 -200304.0      USA  B6BLTT01  CXCUSA         Q
#
#            Country                                            Subject  \
# 0    United States  Balance of payments BPM6 > Current account Bal...
# 1    United States  Balance of payments BPM6 > Current account Bal...
# 2    United States  Balance of payments BPM6 > Current account Bal...
# 3    United States  Balance of payments BPM6 > Current account Bal...
# 4    United States  Balance of payments BPM6 > Current account Bal...
# ..             ...                                                ...
# 250  United States  Balance of payments BPM6 > Current account Bal...
# 251  United States  Balance of payments BPM6 > Current account Bal...
# 252  United States  Balance of payments BPM6 > Current account Bal...
# 253  United States  Balance of payments BPM6 > Current account Bal...
# 254  United States  Balance of payments BPM6 > Current account Bal...
#
#                                               Measure  Frequency
# 0    US Dollars, sum over component sub-periods, s.a.  Quarterly
# 1    US Dollars, sum over component sub-periods, s.a.  Quarterly
# 2    US Dollars, sum over component sub-periods, s.a.  Quarterly
# 3    US Dollars, sum over component sub-periods, s.a.  Quarterly
# 4    US Dollars, sum over component sub-periods, s.a.  Quarterly
# ..                                                ...        ...
# 250  US Dollars, sum over component sub-periods, s.a.  Quarterly
# 251  US Dollars, sum over component sub-periods, s.a.  Quarterly
# 252  US Dollars, sum over component sub-periods, s.a.  Quarterly
# 253  US Dollars, sum over component sub-periods, s.a.  Quarterly
# 254  US Dollars, sum over component sub-periods, s.a.  Quarterly
#
# [255 rows x 18 columns]

# %%
conda install -c conda-forge altair vega_datasets
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/mstables
#
#   added / updated specs:
#     - altair
#     - vega_datasets
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/osx-64::certifi-2025.4.26-p~ --> conda-forge/noarch::certifi-2025.4.26-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge altair-all
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/mstables
#
#   added / updated specs:
#     - altair-all
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-all-5.5.0           |     pyhd8ed1ab_1           7 KB  conda-forge
#     altair_tiles-0.4.0         |     pyhd8ed1ab_0          15 KB  conda-forge
#     anywidget-0.9.18           |     pyhd8ed1ab_0          68 KB  conda-forge
#     arro3-core-0.4.6           |  py312h0ac8f3d_0         1.5 MB  conda-forge
#     aws-c-auth-0.6.21          |       hbc0b158_0          80 KB  conda-forge
#     aws-c-cal-0.5.20           |       hdc31e88_3          36 KB  conda-forge
#     aws-c-common-0.8.5         |       hb7f2c08_0         179 KB  conda-forge
#     aws-c-compression-0.2.16   |       hfb1f584_0          16 KB  conda-forge
#     aws-c-event-stream-0.2.15  |      h6beef47_11          44 KB  conda-forge
#     aws-c-http-0.6.27          |       h40fbe91_3         160 KB  conda-forge
#     aws-c-io-0.13.11           |       hb3bb6ef_2         119 KB  conda-forge
#     aws-c-mqtt-0.7.13          |       h95fd635_9          57 KB  conda-forge
#     aws-c-s3-0.2.1             |       h9f2fa91_0          65 KB  conda-forge
#     aws-c-sdkutils-0.1.7       |       hfb1f584_0          46 KB  conda-forge
#     aws-checksums-0.1.13       |       hfb1f584_5          49 KB  conda-forge
#     aws-crt-cpp-0.18.16        |       h8755ad4_2         187 KB  conda-forge
#     c-ares-1.34.5              |       hf13058a_0         180 KB  conda-forge
#     click-8.2.0                |     pyh707e725_0          86 KB  conda-forge
#     gflags-2.2.2               |    hb1e8313_1004          92 KB  conda-forge
#     glog-0.5.0                 |       h25b26a9_0          94 KB  conda-forge
#     ipywidgets-8.1.7           |     pyhd8ed1ab_0         112 KB  conda-forge
#     jupyterlab_widgets-3.0.15  |     pyhd8ed1ab_0         185 KB  conda-forge
#     krb5-1.21.3                |       h424b1a7_0         1.2 MB
#     libbrotlicommon-1.0.9      |       hb7f2c08_9          68 KB  conda-forge
#     libbrotlidec-1.0.9         |       hb7f2c08_9          31 KB  conda-forge
#     libbrotlienc-1.0.9         |       hb7f2c08_9         273 KB  conda-forge
#     libcurl-8.4.0              |       h726d00d_0         357 KB  conda-forge
#     libev-4.33                 |       h10d778d_2         104 KB  conda-forge
#     libevent-2.1.10            |       h7d65743_4         1.0 MB  conda-forge
#     libnghttp2-1.52.0          |       he2ab024_0         599 KB  conda-forge
#     libssh2-1.11.0             |       hd019ec5_0         253 KB  conda-forge
#     libthrift-0.15.0           |       h1c56d0c_1         357 KB  conda-forge
#     lz4-c-1.9.4                |       hf0c8a7f_0         153 KB  conda-forge
#     mercantile-1.2.1           |     pyhd8ed1ab_1          19 KB  conda-forge
#     psygnal-0.13.0             |     pyhd8ed1ab_0          65 KB  conda-forge
#     snappy-1.1.10              |       h225ccf5_0          34 KB  conda-forge
#     vegafusion-2.0.2           |  py312h33f09d2_0        16.6 MB  conda-forge
#     vl-convert-python-1.7.0    |  py312hb553811_1        20.7 MB  conda-forge
#     widgetsnbextension-4.0.14  |     pyhd8ed1ab_0         868 KB  conda-forge
#     wrapt-1.17.2               |  py312h01d7ebd_0          59 KB  conda-forge
#     xyzservices-2025.4.0       |     pyhd8ed1ab_0          48 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        46.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair-all         conda-forge/noarch::altair-all-5.5.0-pyhd8ed1ab_1
#   altair_tiles       conda-forge/noarch::altair_tiles-0.4.0-pyhd8ed1ab_0
#   anywidget          conda-forge/noarch::anywidget-0.9.18-pyhd8ed1ab_0
#   arro3-core         conda-forge/osx-64::arro3-core-0.4.6-py312h0ac8f3d_0
#   arrow-cpp          pkgs/main/osx-64::arrow-cpp-19.0.0-h2a1e5b1_2
#   aws-c-auth         conda-forge/osx-64::aws-c-auth-0.6.21-hbc0b158_0
#   aws-c-cal          conda-forge/osx-64::aws-c-cal-0.5.20-hdc31e88_3
#   aws-c-common       conda-forge/osx-64::aws-c-common-0.8.5-hb7f2c08_0
#   aws-c-compression  conda-forge/osx-64::aws-c-compression-0.2.16-hfb1f584_0
#   aws-c-event-stream conda-forge/osx-64::aws-c-event-stream-0.2.15-h6beef47_11
#   aws-c-http         conda-forge/osx-64::aws-c-http-0.6.27-h40fbe91_3
#   aws-c-io           conda-forge/osx-64::aws-c-io-0.13.11-hb3bb6ef_2
#   aws-c-mqtt         conda-forge/osx-64::aws-c-mqtt-0.7.13-h95fd635_9
#   aws-c-s3           conda-forge/osx-64::aws-c-s3-0.2.1-h9f2fa91_0
#   aws-c-sdkutils     conda-forge/osx-64::aws-c-sdkutils-0.1.7-hfb1f584_0
#   aws-checksums      conda-forge/osx-64::aws-checksums-0.1.13-hfb1f584_5
#   aws-crt-cpp        conda-forge/osx-64::aws-crt-cpp-0.18.16-h8755ad4_2
#   aws-sdk-cpp        pkgs/main/osx-64::aws-sdk-cpp-1.11.212-h9475118_0
#   c-ares             conda-forge/osx-64::c-ares-1.34.5-hf13058a_0
#   click              conda-forge/noarch::click-8.2.0-pyh707e725_0
#   gflags             conda-forge/osx-64::gflags-2.2.2-hb1e8313_1004
#   glog               conda-forge/osx-64::glog-0.5.0-h25b26a9_0
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.7-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.15-pyhd8ed1ab_0
#   krb5               pkgs/main/osx-64::krb5-1.21.3-h424b1a7_0
#   libabseil          pkgs/main/osx-64::libabseil-20250127.0-cxx17_h548131f_0
#   libbrotlicommon    conda-forge/osx-64::libbrotlicommon-1.0.9-hb7f2c08_9
#   libbrotlidec       conda-forge/osx-64::libbrotlidec-1.0.9-hb7f2c08_9
#   libbrotlienc       conda-forge/osx-64::libbrotlienc-1.0.9-hb7f2c08_9
#   libcurl            conda-forge/osx-64::libcurl-8.4.0-h726d00d_0
#   libedit            pkgs/main/osx-64::libedit-3.1.20230828-h6c40b1e_0
#   libev              conda-forge/osx-64::libev-4.33-h10d778d_2
#   libevent           conda-forge/osx-64::libevent-2.1.10-h7d65743_4
#   libexpat           conda-forge/osx-64::libexpat-2.6.4-h240833e_0
#   libgrpc            pkgs/main/osx-64::libgrpc-1.71.0-hf2926fd_0
#   libnghttp2         conda-forge/osx-64::libnghttp2-1.52.0-he2ab024_0
#   libprotobuf        pkgs/main/osx-64::libprotobuf-5.29.3-h56ee573_0
#   libre2-11          pkgs/main/osx-64::libre2-11-2024.07.02-hab2016f_0
#   libsqlite          conda-forge/osx-64::libsqlite-3.46.0-h1b8f9f3_0
#   libssh2            conda-forge/osx-64::libssh2-1.11.0-hd019ec5_0
#   libthrift          conda-forge/osx-64::libthrift-0.15.0-h1c56d0c_1
#   libzlib            conda-forge/osx-64::libzlib-1.2.13-h87427d6_6
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.4-hf0c8a7f_0
#   mercantile         conda-forge/noarch::mercantile-1.2.1-pyhd8ed1ab_1
#   orc                pkgs/main/osx-64::orc-2.1.1-h4dda5a6_0
#   psygnal            conda-forge/noarch::psygnal-0.13.0-pyhd8ed1ab_0
#   pyarrow            pkgs/main/osx-64::pyarrow-19.0.0-py312h6d0c2b6_1
#   python_abi         conda-forge/noarch::python_abi-3.12-7_cp312
#   re2                pkgs/main/osx-64::re2-2024.07.02-h1962661_0
#   snappy             conda-forge/osx-64::snappy-1.1.10-h225ccf5_0
#   utf8proc           pkgs/main/osx-64::utf8proc-2.6.1-h6c40b1e_1
#   vegafusion         conda-forge/osx-64::vegafusion-2.0.2-py312h33f09d2_0
#   vl-convert-python  conda-forge/osx-64::vl-convert-python-1.7.0-py312hb553811_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.14-pyhd8ed1ab_0
#   wrapt              conda-forge/osx-64::wrapt-1.17.2-py312h01d7ebd_0
#   xyzservices        conda-forge/noarch::xyzservices-2025.4.0-pyhd8ed1ab_0
#   zstd               conda-forge/osx-64::zstd-1.5.6-h915ae27_0
#
# The following packages will be UPDATED:
#
#   zlib                    pkgs/main::zlib-1.2.13-h4b97444_1 --> conda-forge::zlib-1.2.13-h87427d6_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   python                pkgs/main::python-3.12.9-hcd54a6c_0 --> conda-forge::python-3.12.2-h9f0c242_0_cpython
#
#
#
# Downloading and Extracting Packages:
# vl-convert-python-1. | 20.7 MB   |                                       |   0%
# vegafusion-2.0.2     | 16.6 MB   |                                       |   0%
#
# arro3-core-0.4.6     | 1.5 MB    |                                       |   0%
#
#
# krb5-1.21.3          | 1.2 MB    |                                       |   0%
#
#
#
# libevent-2.1.10      | 1.0 MB    |                                       |   0%
#
#
#
#
# widgetsnbextension-4 | 868 KB    |                                       |   0%
#
#
#
#
#
# libnghttp2-1.52.0    | 599 KB    |                                       |   0%
#
#
#
#
#
#
# libcurl-8.4.0        | 357 KB    |                                       |   0%
#
#
#
#
#
#
#
# libthrift-0.15.0     | 357 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 273 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libssh2-1.11.0       | 253 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.18.16  | 187 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_widgets-3 | 185 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.5        | 180 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.8.5   | 179 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.6.27    | 160 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 153 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-io-0.13.11     | 119 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipywidgets-8.1.7     | 112 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libev-4.33           | 104 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glog-0.5.0           | 94 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 92 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# click-8.2.0          | 86 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# krb5-1.21.3          | 1.2 MB    | ##################################### | 100%
#
# arro3-core-0.4.6     | 1.5 MB    | 3                                     |   1%
#
#
#
#
# widgetsnbextension-4 | 868 KB    | 6                                     |   2%
#
#
#
# libevent-2.1.10      | 1.0 MB    | 5                                     |   1%
#
#
# krb5-1.21.3          | 1.2 MB    | ##################################### | 100%
#
#
# krb5-1.21.3          | 1.2 MB    | ##################################### | 100%
#
#
#
# libevent-2.1.10      | 1.0 MB    | ##################################### | 100%
#
#
#
#
# widgetsnbextension-4 | 868 KB    | ##################################### | 100%
#
# arro3-core-0.4.6     | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
# libnghttp2-1.52.0    | 599 KB    | 9                                     |   3%
#
#
#
#
#
#
# libcurl-8.4.0        | 357 KB    | #6                                    |   4%
#
#
#
#
#
# libnghttp2-1.52.0    | 599 KB    | ##################################### | 100%
#
#
#
#
#
#
# libcurl-8.4.0        | 357 KB    | ##################################### | 100%
#
#
#
#
# widgetsnbextension-4 | 868 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libthrift-0.15.0     | 357 KB    | #6                                    |   4%
#
#
#
#
# widgetsnbextension-4 | 868 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 273 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
# libthrift-0.15.0     | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libssh2-1.11.0       | 253 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 273 KB    | ##################################### | 100%
#
# arro3-core-0.4.6     | 1.5 MB    | ##################################### | 100%
#
# arro3-core-0.4.6     | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libssh2-1.11.0       | 253 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.18.16  | 187 KB    | ###1                                  |   9%
#
#
#
#
#
# libnghttp2-1.52.0    | 599 KB    | ##################################### | 100%
#
#
#
#
#
# libnghttp2-1.52.0    | 599 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.18.16  | 187 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_widgets-3 | 185 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.5        | 180 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_widgets-3 | 185 KB    | ##################################### | 100%
# vegafusion-2.0.2     | 16.6 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.5        | 180 KB    | ##################################### | 100%
#
#
#
#
#
#
# libcurl-8.4.0        | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
# libcurl-8.4.0        | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.8.5   | 179 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.8.5   | 179 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.6.27    | 160 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.6.27    | 160 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 273 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 273 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 153 KB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-io-0.13.11     | 119 KB    | ####9                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipywidgets-8.1.7     | 112 KB    | #####2                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-io-0.13.11     | 119 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipywidgets-8.1.7     | 112 KB    | ##################################### | 100%
# vegafusion-2.0.2     | 16.6 MB   | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libev-4.33           | 104 KB    | #####6                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glog-0.5.0           | 94 KB     | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libev-4.33           | 104 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glog-0.5.0           | 94 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# click-8.2.0          | 86 KB     | ######9                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# click-8.2.0          | 86 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 92 KB     | ######4                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 92 KB     | ##################################### | 100%
# vegafusion-2.0.2     | 16.6 MB   | ###########8                          |  32%
#
#
#
#
#
#
#
# libthrift-0.15.0     | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libthrift-0.15.0     | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libssh2-1.11.0       | 253 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# vl-convert-python-1. | 20.7 MB   |                                       |   0%
# vegafusion-2.0.2     | 16.6 MB   | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.18.16  | 187 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.18.16  | 187 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_widgets-3 | 185 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# vl-convert-python-1. | 20.7 MB   | 6                                     |   2%
#
#
#
# libevent-2.1.10      | 1.0 MB    | ##################################### | 100%
#
#
#
# vl-convert-python-1. | 20.7 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.8.5   | 179 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.8.5   | 179 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.5        | 180 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.5        | 180 KB    | ##################################### | 100%
# vegafusion-2.0.2     | 16.6 MB   | ##################################### | 100%
# vegafusion-2.0.2     | 16.6 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.6.27    | 160 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.6.27    | 160 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 153 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-io-0.13.11     | 119 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# vl-convert-python-1. | 20.7 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libev-4.33           | 104 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libev-4.33           | 104 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glog-0.5.0           | 94 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glog-0.5.0           | 94 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# click-8.2.0          | 86 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# click-8.2.0          | 86 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipywidgets-8.1.7     | 112 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# vl-convert-python-1. | 20.7 MB   | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.2.2         | 92 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# vl-convert-python-1. | 20.7 MB   | ##################################### | 100%
# vl-convert-python-1. | 20.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# ECONOMIC INDICATORS DBNOMICS.com

import pandas as pd
import altair as alt

alt.renderers.enable("notebook")
from altair import Chart, Scale, Y

from dbnomics import fetch_series, fetch_series_by_api_link
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/mstables/lib/python3.12/site-packages/altair/utils/plugin_registry.py:207, in PluginRegistry._enable(self, name, **options)
#     206 try:
# --> 207     (ep,) = (
#     208         ep
#     209         for ep in importlib_metadata_get(self.entry_point_group)
#     210         if ep.name == name
#     211     )
#     212 except ValueError as err:
#
# ValueError: not enough values to unpack (expected 1, got 0)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       3 import pandas as pd
#       4 import altair as alt
# ----> 6 alt.renderers.enable("notebook")
#       7 from altair import Chart, Scale, Y
#       9 from dbnomics import fetch_series, fetch_series_by_api_link
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/site-packages/altair/utils/plugin_registry.py:249, in PluginRegistry.enable(self, name, **options)
#     247 if name is None:
#     248     name = self.active
# --> 249 return PluginEnabler(self, name, **options)
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/site-packages/altair/utils/plugin_registry.py:70, in PluginEnabler.__init__(self, registry, name, **options)
#      68 self.options: dict[str, Any] = options
#      69 self.original_state: dict[str, Any] = registry._get_state()
# ---> 70 self.registry._enable(name, **options)
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/site-packages/altair/utils/plugin_registry.py:214, in PluginRegistry._enable(self, name, **options)
#     212 except ValueError as err:
#     213     if name in self.entrypoint_err_messages:
# --> 214         raise ValueError(self.entrypoint_err_messages[name]) from err
#     215     else:
#     216         raise NoSuchEntryPoint(self.entry_point_group, name) from err
#
# ValueError:
# To use the 'notebook' renderer, you must install the vega package
# and the associated Jupyter extension.
# See https://altair-viz.github.io/getting_started/installation.html
# for more information.

# %%
# CURRENCY DATA ONLY
# RATE Limit rate limit of one request per second (1rps)

import urllib.request

url = "https://api.nomics.com/v1/currencies/ticker?key=your-key-here&ids=BTC,ETH,XRP&interval=1d,30d&convert=EUR&platform-currency=ETH&per-page=100&page=1"

base_dbnomics_url = "https://api.nomics.com/v1/currencies/ticker"

print(urllib.request.urlopen(url).read())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/mstables/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/http/client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/http/client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/http/client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/http/client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/http/client.py:1472, in HTTPSConnection.connect(self)
#    1470 "Connect to a host on a given (SSL) port."
# -> 1472 super().connect()
#    1474 if self._tunnel_host:
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/http/client.py:1003, in HTTPConnection.connect(self)
#    1002 sys.audit("http.client.connect", self, self.host, self.port)
# -> 1003 self.sock = self._create_connection(
#    1004     (self.host,self.port), self.timeout, self.source_address)
#    1005 # Might fail in OSs that don't implement TCP_NODELAY
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/socket.py:841, in create_connection(address, timeout, source_address, all_errors)
#     840 exceptions = []
# --> 841 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     842     af, socktype, proto, canonname, sa = res
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/socket.py:978, in getaddrinfo(host, port, family, type, proto, flags)
#     977 addrlist = []
# --> 978 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     979     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[7], line 10
#       6 url = "https://api.nomics.com/v1/currencies/ticker?key=your-key-here&ids=BTC,ETH,XRP&interval=1d,30d&convert=EUR&platform-currency=ETH&per-page=100&page=1"
#       8 base_dbnomics_url = "https://api.nomics.com/v1/currencies/ticker"
# ---> 10 print(urllib.request.urlopen(url).read())
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/urllib/request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/urllib/request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/urllib/request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File /opt/anaconda3/envs/mstables/lib/python3.12/urllib/request.py:1347, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344         h.request(req.get_method(), req.selector, req.data, headers,
#    1345                   encode_chunked=req.has_header('Transfer-encoding'))
#    1346     except OSError as err: # timeout error
# -> 1347         raise URLError(err)
#    1348     r = h.getresponse()
#    1349 except:
#
# URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>

# %%
import altair as alt

# load a simple dataset as a pandas DataFrame
from vega_datasets import data

cars = data.cars()

alt.Chart(cars).mark_point().encode(
    x="Horsepower", y="Miles_per_Gallon", color="Origin",
).interactive()
# Out:
# alt.Chart(...)

# %%
BTC_data = [
    {
        "currency": "BTC",
        "id": "BTC",
        "status": "active",
        "price": "8451.36516421",
        "price_date": "2019-06-14T00:00:00Z",
        "price_timestamp": "2019-06-14T12:35:00Z",
        "symbol": "BTC",
        "circulating_supply": "17758462",
        "max_supply": "21000000",
        "name": "Bitcoin",
        "logo_url": "https://s3.us-east-2.amazonaws.com/nomics-api/static/images/currencies/btc.svg",
        "market_cap": "150083247116.70",
        "market_cap_dominance": "0.4080",
        "transparent_market_cap": "150003247116.70",
        "num_exchanges": "357",
        "num_pairs": "42118",
        "num_pairs_unmapped": "4591",
        "first_candle": "2011-08-18T00:00:00Z",
        "first_trade": "2011-08-18T00:00:00Z",
        "first_order_book": "2017-01-06T00:00:00Z",
        "first_priced_at": "2017-08-18T18:22:19Z",
        "rank": "1",
        "rank_delta": "0",
        "high": "19404.81116899",
        "high_timestamp": "2017-12-16",
        "1d": {
            "price_change": "269.75208019",
            "price_change_pct": "0.03297053",
            "volume": "1110989572.04",
            "volume_change": "-24130098.49",
            "volume_change_pct": "-0.02",
            "market_cap_change": "4805518049.63",
            "market_cap_change_pct": "0.03",
            "transparent_market_cap_change": "4800518049.00",
            "transparent_market_cap_change_pct": "0.0430",
            "volume_transparency": [
                {
                    "grade": "A",
                    "volume": "2144455081.37",
                    "volume_change": "-235524941.08",
                    "volume_change_pct": "-0.10",
                },
                {
                    "grade": "B",
                    "volume": "15856762.85",
                    "volume_change": "-6854329.88",
                    "volume_change_pct": "-0.30",
                },
            ],
        },
    }
]
