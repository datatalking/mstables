# %%
# https://docs.data.nasdaq.com/docs/in-depth-usage
# !pip3 install nasdaq-data-link
# !pip3 install quandl
# !pip3 install pandas

# %%
import pandas as pd

pd.read_csv("https://www.quandl.com/api/v3/datatables/WIKI/PRICES?qopts.export=true&api_key=q73DzEBaB3Y9Tamkwswg", nrows=100)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/jq/9dbfmyhn6s98d705yc81nqym0000gn/T/ipykernel_20656/2785979054.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 pd.read_csv("https://www.quandl.com/api/v3/datatables/WIKI/PRICES?qopts.export=true&api_key=q73DzEBaB3Y9Tamkwswg", nrows=100)
#
# ~/opt/anaconda3/envs/mstables/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import quandl

quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
data = quandl.get_table("WIKI/PRICES", paginate=True)

#pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/dplyr/storms.csv", nrows=10)

data

# %%
import nasdaqdatalink

quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
mydata = nasdaqdatalink.get("FRED/GDP")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jq/9dbfmyhn6s98d705yc81nqym0000gn/T/ipykernel_20656/873183704.py in <module>
#       1 import nasdaqdatalink
#       2
# ----> 3 quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
#       4 mydata = nasdaqdatalink.get("FRED/GDP")
#
# NameError: name 'quandl' is not defined

# %%
quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
quandl.get_table("INDICATORS", paginate=True)

# %%
quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
quandl.get_table('ZILLOW/DATA', indicator_id='ZSFH', region_id='99999')

# %%
quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
nasdaqdatalink.bulkdownload("ZEA")

# %%
quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
nasdaqdatalink.get("FRED/GDP", transformation="rdiff")

# %%
quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
nasdaqdatalink.get("EIA/PET_RWTC_D", collapse="monthly")

# %%
quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
nasdaqdatalink.get("WIKI/AAPL", rows=5)

# %%
quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
nasdaqdatalink.get(["NSE/OIL.1", "WIKI/AAPL.4"])

# %%
quandl.ApiConfig.api_key = 'q73DzEBaB3Y9Tamkwswg'
nasdaqdatalink.get("FRED/GDP", start_date="2001-12-31", end_date="2005-12-31")

# %%
nasdaqdatalink.get("EIA/PET_RWTC_D", returns="numpy")

# %%
data = nasdaqdatalink.get("EIA/PET_RWTC_D") # paginate=True

# %% [markdown]
# The tables API is limited to 10,000 rows per call. However, when using the Python library, appending the argument paginate=True will extend the limit to 1,000,000 rows. As such, we recommend using paginate=True for all calls. Please note that some datasets can return more data than Python allows. If this occurs, you will need to further filter your call to download less data, as outlined in the examples below. Or you may consider using data exporter.

# %%
#api_key=q73DzEBaB3Y9Tamkwswg
#https://data.nasdaq.com/api/v3/datatables/MER/F1.csv
